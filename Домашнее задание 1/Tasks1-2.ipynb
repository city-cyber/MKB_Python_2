# %% [markdown]
# Задание 1
# Напишите код на Python в среде Jupyter Notebook или Google Colab для решения
# следующей задачи.
# Дана переменная, в которой хранится слово из латинских букв. Напишите код, который
# выводит на экран:
# – среднюю букву, если число букв в слове нечётное;
# – две средних буквы, если число букв чётное.
# Пример работы программы:
# 1. word =’test' Результат: es
# 2. word = 'testing' Результат: t

# %%
# Пример 1
word = 'test'
word_length = len(word)

if word_length % 2 == 0:  # Четная длина
    middle_index = word_length // 2
    result = word[middle_index - 1:middle_index + 1]
else:  # Нечетная длина
    middle_index = word_length // 2
    result = word[middle_index]
print(f"Слово: '{word}', Результат: '{result}'")
# Out:
# Слово: 'test', Результат: 'es'

# %%
# Пример 2
word = 'testing'
word_length = len(word)

if word_length % 2 == 0:  # Четная длина
    middle_index = word_length // 2
    result = word[middle_index - 1:middle_index + 1]
else:  # Нечетная длина
    middle_index = word_length // 2
    result = word[middle_index]
print(f"Слово: '{word}', Результат: '{result}'")
# Out:
# Слово: 'testing', Результат: 't'

# %% [markdown]
# Задание 2.
# Напишите код на Python в среде Jupyter Notebook или Google Colab для решения
# следующей задачи.
# Вы делаете MVP (минимально жизнеспособный продукт) dating-сервиса. У вас есть
# список юношей и девушек.
# Выдвигаем гипотезу: лучшие рекомендации получатся, если просто отсортировать
# имена по алфавиту и познакомить людей с одинаковыми индексами после сортировки.
# Но вы не будете никого знакомить, если кто-то может остаться без пары.
# Примеры работы программы:
# boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
# girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
# Результат:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
# boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']
# girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
# Результат: Внимание, кто-то может остаться без пары!

# %%
# Задание 2: MVP Dating-сервиса

# Пример 1: Списки одинаковой длины
boys1 = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls1 = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

# Пример 2: Списки разной длины
boys2 = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']
girls2 = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

# --- Решение для первого набора данных ---
print("--- Пример 1 ---")
boys = boys1
girls = girls1

if len(boys) != len(girls):
    print("Внимание, кто-то может остаться без пары!")
else:
    # 1. Отсортировать списки по алфавиту
    sorted_boys = sorted(boys)
    sorted_girls = sorted(girls)

    print("Идеальные пары:")
    # 2. Объединить людей с одинаковыми индексами
    # zip() удобно для итерации по двум спискам одновременно
    for boy, girl in zip(sorted_boys, sorted_girls):
        print(f"{boy} и {girl}")

print("\n--- Пример 2 ---")
# --- Решение для второго набора данных ---
boys = boys2
girls = girls2

if len(boys) != len(girls):
    print("Внимание, кто-то может остаться без пары!")
else:
    sorted_boys = sorted(boys)
    sorted_girls = sorted(girls)
    print("Идеальные пары:")
    for boy, girl in zip(sorted_boys, sorted_girls):
        print(f"{boy} и {girl}")
# Out:
# --- Пример 1 ---
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha
#
# --- Пример 2 ---
# Внимание, кто-то может остаться без пары!
